# %%
#Lakshya Sonawane
#EXP2 : study of list in python

# %%
list1 = ["apple", "banana", "cherry"]
print(list1)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list2=["abc", 34, True, 40, "male"]
print(list2)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
list3 = ["apple","banana","orange","cherry","mango","kiwi"]
print(list3[2])
print(list3[-4])
print(list3[2:5])
print(list3[:4])
# Out:
# orange
# orange
# ['orange', 'cherry', 'mango']
# ['apple', 'banana', 'orange', 'cherry']

# %%
list4  = ["apple","orange","mango"]
list4[1]=2
print(list4)
# Out:
# ['apple', 2, 'mango']

# %%
list5  = ["apple","orange","cherry"]
list5.append("mango")
print(list5)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list6 = ["apple","banana","cherry"]
list6.insert(1,"mango")
print(list6)
# Out:
# ['apple', 'mango', 'banana', 'cherry']

# %%
list7 = ["apple","banana","cherry"]
list8 = ["apple","orange","mango"]
list7.extend(list8)
print(list7)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'orange', 'mango']

# %%
marks = [90,82,66,76,33]
print(len(marks))
print(max(marks))
print(min(marks))
print(sum(marks))
print(sorted(marks))
print(sum(marks)/len(marks))
# Out:
# 5
# 90
# 33
# 347
# [33, 66, 76, 82, 90]
# 69.4

# %%
grocery = ["potatoes","chips","Onions","Oil","Wheat"]
grocery.append("Pulses")
grocery.remove("potatoes")
grocery.remove("chips")
print(grocery)
# Out:
# ['Onions', 'Oil', 'Wheat', 'Pulses']
